# %%
for i in range(100):
    t = 101 + i
    l = 1 + i
    m = format(l, 'x')
    #print("interface TenGigE0/7/0/15." + str(t))
    #print("description IXIA_04/05")
    #print("service-policy input Core-Qos")
    #print("service-policy output Core-Qos")
    #print("vrf LTE")    
    print("  2001:" + str(t) + "::/32,")
    #print("ipv6 address 2001:db8:160:" + str(m) + "::1/64")
    #print("dampening")
    #print("encapsulation dot1q " + str(t))
    #print("")
# Out:
#   2001:101::/32,
#   2001:102::/32,
#   2001:103::/32,
#   2001:104::/32,
#   2001:105::/32,
#   2001:106::/32,
#   2001:107::/32,
#   2001:108::/32,
#   2001:109::/32,
#   2001:110::/32,
#   2001:111::/32,
#   2001:112::/32,
#   2001:113::/32,
#   2001:114::/32,
#   2001:115::/32,
#   2001:116::/32,
#   2001:117::/32,
#   2001:118::/32,
#   2001:119::/32,
#   2001:120::/32,
#   2001:121::/32,
#   2001:122::/32,
#   2001:123::/32,
#   2001:124::/32,
#   2001:125::/32,
#   2001:126::/32,
#   2001:127::/32,
#   2001:128::/32,
#   2001:129::/32,
#   2001:130::/32,
#   2001:131::/32,
#   2001:132::/32,
#   2001:133::/32,
#   2001:134::/32,
#   2001:135::/32,
#   2001:136::/32,
#   2001:137::/32,
#   2001:138::/32,
#   2001:139::/32,
#   2001:140::/32,
#   2001:141::/32,
#   2001:142::/32,
#   2001:143::/32,
#   2001:144::/32,
#   2001:145::/32,
#   2001:146::/32,
#   2001:147::/32,
#   2001:148::/32,
#   2001:149::/32,
#   2001:150::/32,
#   2001:151::/32,
#   2001:152::/32,
# ...

# %%
for i in range(100):
    t = 101 + i
    l = 1 + i
    m = format(l, 'x')
    #print("interface TenGigE0/7/0/15." + str(t))
    #print("description IXIA_04/05")
    #print("service-policy input Core-Qos")
    #print("service-policy output Core-Qos")
    #print("vrf LTE")    
    print(" network 100." + str(t) + ".0.0/16 route-policy ORIGIN")
    #print("ipv6 address 2001:db8:160:" + str(m) + "::1/64")
    #print("dampening")
    #print("encapsulation dot1q " + str(t))
    #print("")
# Out:
#  network 100.101.0.0/16 route-policy ORIGIN
#  network 100.102.0.0/16 route-policy ORIGIN
#  network 100.103.0.0/16 route-policy ORIGIN
#  network 100.104.0.0/16 route-policy ORIGIN
#  network 100.105.0.0/16 route-policy ORIGIN
#  network 100.106.0.0/16 route-policy ORIGIN
#  network 100.107.0.0/16 route-policy ORIGIN
#  network 100.108.0.0/16 route-policy ORIGIN
#  network 100.109.0.0/16 route-policy ORIGIN
#  network 100.110.0.0/16 route-policy ORIGIN
#  network 100.111.0.0/16 route-policy ORIGIN
#  network 100.112.0.0/16 route-policy ORIGIN
#  network 100.113.0.0/16 route-policy ORIGIN
#  network 100.114.0.0/16 route-policy ORIGIN
#  network 100.115.0.0/16 route-policy ORIGIN
#  network 100.116.0.0/16 route-policy ORIGIN
#  network 100.117.0.0/16 route-policy ORIGIN
#  network 100.118.0.0/16 route-policy ORIGIN
#  network 100.119.0.0/16 route-policy ORIGIN
#  network 100.120.0.0/16 route-policy ORIGIN
#  network 100.121.0.0/16 route-policy ORIGIN
# ...

# %%
for i in range(45):
    t = 2156 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/7/0/15." + str(t))
    print("description IXIA_04/05")
    #print("service-policy input Core-Qos")
    #print("service-policy output Core-Qos")
    #print("vrf LTE")    
    print("ipv4 address 19.2." + str(i) + ".1 255.255.255.0")
    #print("ipv6 address 2001:db8:160:" + str(m) + "::1/64")
    print("dampening")
    print("encapsulation dot1q " + str(t))
    print("")
# Out:
# interface TenGigE0/7/0/15.2156
# description IXIA_04/05
# ipv4 address 19.2.0.1 255.255.255.0
# dampening
# encapsulation dot1q 2156
#
# interface TenGigE0/7/0/15.2157
# description IXIA_04/05
# ipv4 address 19.2.1.1 255.255.255.0
# dampening
# encapsulation dot1q 2157
#
# interface TenGigE0/7/0/15.2158
# description IXIA_04/05
# ipv4 address 19.2.2.1 255.255.255.0
# dampening
# encapsulation dot1q 2158
#
# interface TenGigE0/7/0/15.2159
# description IXIA_04/05
# ipv4 address 19.2.3.1 255.255.255.0
# dampening
# encapsulation dot1q 2159
#
# interface TenGigE0/7/0/15.2160
# description IXIA_04/05
# ipv4 address 19.2.4.1 255.255.255.0
# dampening
# encapsulation dot1q 2160
#
# interface TenGigE0/7/0/15.2161
# description IXIA_04/05
# ipv4 address 19.2.5.1 255.255.255.0
# dampening
# encapsulation dot1q 2161
#
# interface TenGigE0/7/0/15.2162
# description IXIA_04/05
# ipv4 address 19.2.6.1 255.255.255.0
# dampening
# encapsulation dot1q 2162
#
# interface TenGigE0/7/0/15.2163
# ...

# %%
for i in range(10):
    t = 1551 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/4." + str(t))
    print("description IXIA_04/03")
    print("service-policy input Core-Qos")
    print("service-policy output Core-Qos")
    #print("vrf LTE")    
    print("ipv4 address 15.1." + str(l) + ".1 255.255.255.0")
    print("ipv6 address 2001:db8:150:" + str(m) + "::1/64")
    print("dampening")
    print("encapsulation dot1q " + str(t))
    print("")
# Out:
# interface TenGigE0/0/0/4.1551
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 15.1.1.1 255.255.255.0
# ipv6 address 2001:db8:150:1::1/64
# dampening
# encapsulation dot1q 1551
#
# interface TenGigE0/0/0/4.1552
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 15.1.2.1 255.255.255.0
# ipv6 address 2001:db8:150:2::1/64
# dampening
# encapsulation dot1q 1552
#
# interface TenGigE0/0/0/4.1553
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 15.1.3.1 255.255.255.0
# ipv6 address 2001:db8:150:3::1/64
# dampening
# encapsulation dot1q 1553
#
# interface TenGigE0/0/0/4.1554
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 15.1.4.1 255.255.255.0
# ipv6 address 2001:db8:150:4::1/64
# dampening
# encapsulation dot1q 1554
#
# interface TenGigE0/0/0/4.1555
# ...

# %%
for i in range(200):
    t = 1551 + i
    l = 1 + i
    m = format(l, 'x')
    ##print("interface TenGigE0/0/0/4." + str(t))
    #print("description IXIA_04/03")
    #print("service-policy input Core-Qos")
    #print("service-policy output Core-Qos")
    #print("vrf LTE")    
    #print("ipv4 address 15.1." + str(l) + ".1 255.255.255.0")
    print("  2001:" + str(m) + "::/32,")
    #print("dampening")
    #print("encapsulation dot1q " + str(t))
    #print("")
# Out:
#   2001:101::/32,
#   2001:102::/32,
#   2001:103::/32,
#   2001:104::/32,
#   2001:105::/32,
#   2001:106::/32,
#   2001:107::/32,
#   2001:108::/32,
#   2001:109::/32,
#   2001:10a::/32,
#   2001:10b::/32,
#   2001:10c::/32,
#   2001:10d::/32,
#   2001:10e::/32,
#   2001:10f::/32,
#   2001:1010::/32,
#   2001:1011::/32,
#   2001:1012::/32,
#   2001:1013::/32,
#   2001:1014::/32,
#   2001:1015::/32,
#   2001:1016::/32,
#   2001:1017::/32,
#   2001:1018::/32,
#   2001:1019::/32,
#   2001:101a::/32,
#   2001:101b::/32,
#   2001:101c::/32,
#   2001:101d::/32,
#   2001:101e::/32,
#   2001:101f::/32,
#   2001:1020::/32,
#   2001:1021::/32,
#   2001:1022::/32,
#   2001:1023::/32,
#   2001:1024::/32,
#   2001:1025::/32,
#   2001:1026::/32,
#   2001:1027::/32,
#   2001:1028::/32,
#   2001:1029::/32,
#   2001:102a::/32,
#   2001:102b::/32,
#   2001:102c::/32,
#   2001:102d::/32,
#   2001:102e::/32,
#   2001:102f::/32,
#   2001:1030::/32,
#   2001:1031::/32,
#   2001:1032::/32,
# ...

# %%
for i in range(100):
    t =  + i
    l = 1 + i
    m = format(l, 'x')
    #print("interface TenGigE0/0/0/4." + str(t))
    #print("description IXIA_04/03")
    #print("service-policy input Core-Qos")
    #print("service-policy output Core-Qos")
    #print("vrf LTE")    
    #print("ipv4 address 15.1." + str(l) + ".1 255.255.255.0")
    print("  2001:" + str(m) + "::/32")
    #print("dampening")
    #print("encapsulation dot1q " + str(t))
    #print("")
# Out:
#   2001:64::/32
#   2001:65::/32
#   2001:66::/32
#   2001:67::/32
#   2001:68::/32
#   2001:69::/32
#   2001:6a::/32
#   2001:6b::/32
#   2001:6c::/32
#   2001:6d::/32
#   2001:6e::/32
#   2001:6f::/32
#   2001:70::/32
#   2001:71::/32
#   2001:72::/32
#   2001:73::/32
#   2001:74::/32
#   2001:75::/32
#   2001:76::/32
#   2001:77::/32
#   2001:78::/32
#   2001:79::/32
#   2001:7a::/32
#   2001:7b::/32
#   2001:7c::/32
#   2001:7d::/32
#   2001:7e::/32
#   2001:7f::/32
#   2001:80::/32
#   2001:81::/32
#   2001:82::/32
#   2001:83::/32
#   2001:84::/32
#   2001:85::/32
#   2001:86::/32
#   2001:87::/32
#   2001:88::/32
#   2001:89::/32
#   2001:8a::/32
#   2001:8b::/32
#   2001:8c::/32
#   2001:8d::/32
#   2001:8e::/32
#   2001:8f::/32
#   2001:90::/32
#   2001:91::/32
#   2001:92::/32
#   2001:93::/32
#   2001:94::/32
#   2001:95::/32
#   2001:96::/32
#   2001:97::/32
#   2001:98::/32
#   2001:99::/32
#   2001:9a::/32
#   2001:9b::/32
#   2001:9c::/32
#   2001:9d::/32
# ...

# %%
for i in range(101):
    t = 2456 + i
    l =  i + 1
    p = 256 + i
    m = format(p, 'x')
    #print("interface HundredGigE0/11/0/1." + str(t))
    #print("description IXIA_04/08")
    #print("service-policy input Core-Qos")
    #print("service-policy output Core-Qos")
    #print("vrf LTE") 
    #print("ipv4 address 22.2." + str(l) + ".1 255.255.255.0")
    print("  2001:" + str(m) + "::/32,")
    #print("dampening")
    #print("encapsulation dot1q " + str(t))
    #print("")
# Out:
#   2001:100::/32,
#   2001:101::/32,
#   2001:102::/32,
#   2001:103::/32,
#   2001:104::/32,
#   2001:105::/32,
#   2001:106::/32,
#   2001:107::/32,
#   2001:108::/32,
#   2001:109::/32,
#   2001:10a::/32,
#   2001:10b::/32,
#   2001:10c::/32,
#   2001:10d::/32,
#   2001:10e::/32,
#   2001:10f::/32,
#   2001:110::/32,
#   2001:111::/32,
#   2001:112::/32,
#   2001:113::/32,
#   2001:114::/32,
#   2001:115::/32,
#   2001:116::/32,
#   2001:117::/32,
#   2001:118::/32,
#   2001:119::/32,
#   2001:11a::/32,
#   2001:11b::/32,
#   2001:11c::/32,
#   2001:11d::/32,
#   2001:11e::/32,
#   2001:11f::/32,
#   2001:120::/32,
#   2001:121::/32,
#   2001:122::/32,
#   2001:123::/32,
#   2001:124::/32,
#   2001:125::/32,
#   2001:126::/32,
#   2001:127::/32,
#   2001:128::/32,
#   2001:129::/32,
#   2001:12a::/32,
#   2001:12b::/32,
#   2001:12c::/32,
#   2001:12d::/32,
#   2001:12e::/32,
#   2001:12f::/32,
#   2001:130::/32,
#   2001:131::/32,
#   2001:132::/32,
#   2001:133::/32,
# ...

# %%
for i in range(255):
    t = 2201 + i
    l = 1 + i
    m = format(l, 'x')
    print("no interface HundredGigE0/11/0/2." + str(t))
    print("")
# Out:
# no interface HundredGigE0/11/0/2.2201
#
# no interface HundredGigE0/11/0/2.2202
#
# no interface HundredGigE0/11/0/2.2203
#
# no interface HundredGigE0/11/0/2.2204
#
# no interface HundredGigE0/11/0/2.2205
#
# no interface HundredGigE0/11/0/2.2206
#
# no interface HundredGigE0/11/0/2.2207
#
# no interface HundredGigE0/11/0/2.2208
#
# no interface HundredGigE0/11/0/2.2209
#
# no interface HundredGigE0/11/0/2.2210
#
# no interface HundredGigE0/11/0/2.2211
#
# no interface HundredGigE0/11/0/2.2212
#
# no interface HundredGigE0/11/0/2.2213
#
# no interface HundredGigE0/11/0/2.2214
#
# no interface HundredGigE0/11/0/2.2215
#
# no interface HundredGigE0/11/0/2.2216
#
# no interface HundredGigE0/11/0/2.2217
#
# no interface HundredGigE0/11/0/2.2218
#
# no interface HundredGigE0/11/0/2.2219
#
# no interface HundredGigE0/11/0/2.2220
#
# no interface HundredGigE0/11/0/2.2221
#
# no interface HundredGigE0/11/0/2.2222
#
# no interface HundredGigE0/11/0/2.2223
#
# ...

# %%
for i in range(105):
    t = 2456 + i
    l =  i
    p = 256 + i
    m = format(p, 'x')
    print("no interface HundredGigE0/11/0/2." + str(t))
    print("")
# Out:
# no interface HundredGigE0/11/0/2.2456
#
# no interface HundredGigE0/11/0/2.2457
#
# no interface HundredGigE0/11/0/2.2458
#
# no interface HundredGigE0/11/0/2.2459
#
# no interface HundredGigE0/11/0/2.2460
#
# no interface HundredGigE0/11/0/2.2461
#
# no interface HundredGigE0/11/0/2.2462
#
# no interface HundredGigE0/11/0/2.2463
#
# no interface HundredGigE0/11/0/2.2464
#
# no interface HundredGigE0/11/0/2.2465
#
# no interface HundredGigE0/11/0/2.2466
#
# no interface HundredGigE0/11/0/2.2467
#
# no interface HundredGigE0/11/0/2.2468
#
# no interface HundredGigE0/11/0/2.2469
#
# no interface HundredGigE0/11/0/2.2470
#
# no interface HundredGigE0/11/0/2.2471
#
# no interface HundredGigE0/11/0/2.2472
#
# no interface HundredGigE0/11/0/2.2473
#
# no interface HundredGigE0/11/0/2.2474
#
# no interface HundredGigE0/11/0/2.2475
#
# no interface HundredGigE0/11/0/2.2476
#
# no interface HundredGigE0/11/0/2.2477
#
# no interface HundredGigE0/11/0/2.2478
#
# ...

# %%
for i in range(105):
    t = 2456 + i
    l =  i
    p = 256 + i
    k = 2456 + i
    m = format(p, 'x')
    print("   no neighbor 22.2." + str(l) + ".2")
    print("   remote-as " + str(k))
    print("   description IXIA_05/03")
    print("   address-family ipv4 unicast")
    print("    route-policy PERMIT in")
    print("    route-policy PERMIT out")
    print("")
# Out:
#    no neighbor 22.2.0.2
#
#    no neighbor 22.2.1.2
#
#    no neighbor 22.2.2.2
#
#    no neighbor 22.2.3.2
#
#    no neighbor 22.2.4.2
#
#    no neighbor 22.2.5.2
#
#    no neighbor 22.2.6.2
#
#    no neighbor 22.2.7.2
#
#    no neighbor 22.2.8.2
#
#    no neighbor 22.2.9.2
#
#    no neighbor 22.2.10.2
#
#    no neighbor 22.2.11.2
#
#    no neighbor 22.2.12.2
#
#    no neighbor 22.2.13.2
#
#    no neighbor 22.2.14.2
#
#    no neighbor 22.2.15.2
#
#    no neighbor 22.2.16.2
#
#    no neighbor 22.2.17.2
#
#    no neighbor 22.2.18.2
#
#    no neighbor 22.2.19.2
#
#    no neighbor 22.2.20.2
#
#    no neighbor 22.2.21.2
#
#    no neighbor 22.2.22.2
#
#    no neighbor 22.2.23.2
#
#    no neighbor 22.2.24.2
#
#    no neighbor 22.2.25.2
#
#    no neighbor 22.2.26.2
#
#    no neighbor 22.2.27.2
#
#    no neighbor 22.2.28.2
#
#    no neighbor 22.2.29.2
#
#    no neighbor 22.2.30.2
#
#    no neighbor 22.2.31.2
#
#    no neighbor 22.2.32.2
#
#    no neighbor 22.2.33.2
#
# ...

# %%
for i in range(245):
    t = 2211 + i
    l = 11 + i
    m = format(l, 'x')
    k = 2201 + i
    print("   no neighbor 22.1." + str(l) + ".2")   
    #print("   remote-as " + str(k))
    #print("   description IXIA_05/03")
    #print("   address-family ipv4 unicast")
    #print("    route-policy PERMIT in")
    #print("    route-policy PERMIT out")
    print("")
# Out:
#    no neighbor 22.1.11.2
#
#    no neighbor 22.1.12.2
#
#    no neighbor 22.1.13.2
#
#    no neighbor 22.1.14.2
#
#    no neighbor 22.1.15.2
#
#    no neighbor 22.1.16.2
#
#    no neighbor 22.1.17.2
#
#    no neighbor 22.1.18.2
#
#    no neighbor 22.1.19.2
#
#    no neighbor 22.1.20.2
#
#    no neighbor 22.1.21.2
#
#    no neighbor 22.1.22.2
#
#    no neighbor 22.1.23.2
#
#    no neighbor 22.1.24.2
#
#    no neighbor 22.1.25.2
#
#    no neighbor 22.1.26.2
#
#    no neighbor 22.1.27.2
#
#    no neighbor 22.1.28.2
#
#    no neighbor 22.1.29.2
#
#    no neighbor 22.1.30.2
#
#    no neighbor 22.1.31.2
#
#    no neighbor 22.1.32.2
#
#    no neighbor 22.1.33.2
#
#    no neighbor 22.1.34.2
#
#    no neighbor 22.1.35.2
#
#    no neighbor 22.1.36.2
#
#    no neighbor 22.1.37.2
#
#    no neighbor 22.1.38.2
#
#    no neighbor 22.1.39.2
#
#    no neighbor 22.1.40.2
#
#    no neighbor 22.1.41.2
#
#    no neighbor 22.1.42.2
#
#    no neighbor 22.1.43.2
#
#    no neighbor 22.1.44.2
#
# ...

# %%
for i in range(255):
    t = 2201 + i
    l = 1 + i
    m = format(l, 'x')
    k = 2201 + i
    print("   no neighbor 22.1." + str(l) + ".2")
# Out:
#    no neighbor 22.1.1.2
#    no neighbor 22.1.2.2
#    no neighbor 22.1.3.2
#    no neighbor 22.1.4.2
#    no neighbor 22.1.5.2
#    no neighbor 22.1.6.2
#    no neighbor 22.1.7.2
#    no neighbor 22.1.8.2
#    no neighbor 22.1.9.2
#    no neighbor 22.1.10.2
#    no neighbor 22.1.11.2
#    no neighbor 22.1.12.2
#    no neighbor 22.1.13.2
#    no neighbor 22.1.14.2
#    no neighbor 22.1.15.2
#    no neighbor 22.1.16.2
#    no neighbor 22.1.17.2
#    no neighbor 22.1.18.2
#    no neighbor 22.1.19.2
#    no neighbor 22.1.20.2
#    no neighbor 22.1.21.2
#    no neighbor 22.1.22.2
#    no neighbor 22.1.23.2
#    no neighbor 22.1.24.2
#    no neighbor 22.1.25.2
#    no neighbor 22.1.26.2
#    no neighbor 22.1.27.2
#    no neighbor 22.1.28.2
#    no neighbor 22.1.29.2
#    no neighbor 22.1.30.2
#    no neighbor 22.1.31.2
#    no neighbor 22.1.32.2
#    no neighbor 22.1.33.2
#    no neighbor 22.1.34.2
#    no neighbor 22.1.35.2
#    no neighbor 22.1.36.2
#    no neighbor 22.1.37.2
# ...

# %%
for i in range(105):
    t = 2456 + i
    l =  i
    p = 256 + i
    k = 2456 + i
    m = format(p, 'x')
    print("   no neighbor 22.2." + str(l) + ".2")
# Out:
#    no neighbor 22.2.0.2
#    no neighbor 22.2.1.2
#    no neighbor 22.2.2.2
#    no neighbor 22.2.3.2
#    no neighbor 22.2.4.2
#    no neighbor 22.2.5.2
#    no neighbor 22.2.6.2
#    no neighbor 22.2.7.2
#    no neighbor 22.2.8.2
#    no neighbor 22.2.9.2
#    no neighbor 22.2.10.2
#    no neighbor 22.2.11.2
#    no neighbor 22.2.12.2
#    no neighbor 22.2.13.2
#    no neighbor 22.2.14.2
#    no neighbor 22.2.15.2
#    no neighbor 22.2.16.2
#    no neighbor 22.2.17.2
#    no neighbor 22.2.18.2
#    no neighbor 22.2.19.2
#    no neighbor 22.2.20.2
#    no neighbor 22.2.21.2
#    no neighbor 22.2.22.2
#    no neighbor 22.2.23.2
#    no neighbor 22.2.24.2
#    no neighbor 22.2.25.2
#    no neighbor 22.2.26.2
#    no neighbor 22.2.27.2
#    no neighbor 22.2.28.2
#    no neighbor 22.2.29.2
#    no neighbor 22.2.30.2
#    no neighbor 22.2.31.2
#    no neighbor 22.2.32.2
#    no neighbor 22.2.33.2
#    no neighbor 22.2.34.2
#    no neighbor 22.2.35.2
#    no neighbor 22.2.36.2
# ...

# %%
for i in range(10):
    t = 1551 + i
    l =  i +1
    m = format(l, 'x')
    k = 1551 + i
    print("   neighbor 2001:db8:150:" + str(m) + "::2")
    print("   remote-as " + str(k))
    print("   description IXIA_04/03")
    print("   address-family ipv6 unicast")
    print("    route-policy PERMIT in")
    print("    route-policy PERMIT out")
    print("")
# Out:
#    neighbor 2001:db8:150:1::2
#    remote-as 1551
#    description IXIA_04/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:2::2
#    remote-as 1552
#    description IXIA_04/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:3::2
#    remote-as 1553
#    description IXIA_04/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:4::2
#    remote-as 1554
#    description IXIA_04/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:5::2
#    remote-as 1555
#    description IXIA_04/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:6::2
#    remote-as 1556
#    description IXIA_04/03
#    address-family ipv6 unicast
# ...

# %%
for i in range(45):
    t = 1756 + i
    l =  i
    p = 256 + i
    k = 1756 + i
    m = format(p, 'x')
    print("   neighbor 2001:db8:150:" + str(m) + "::2")
    print("   remote-as " + str(k))
    print("   description IXIA_05/03")
    print("   address-family ipv6 unicast")
    print("    route-policy PERMIT in")
    print("    route-policy PERMIT out")
    print("")
# Out:
#    neighbor 2001:db8:150:100::2
#    remote-as 1756
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:101::2
#    remote-as 1757
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:102::2
#    remote-as 1758
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:103::2
#    remote-as 1759
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:104::2
#    remote-as 1760
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:150:105::2
#    remote-as 1761
#    description IXIA_05/03
#    address-family ipv6 unicast
# ...

# %%
for i in range(150):
    t = 1401 + i
    l =  i
    p = 256 + i
    k = 1756 + i
    m = format(p, 'x')
    print(" neighbor 14.1." + str(l+1) + ".2")
    print("   use neighbor-group ACS-FULL")
    print("   description IXIA_04/03")
    #print("   address-family ipv4 unicast")
    #print("    route-policy PERMIT in")
    #print("    route-policy PERMIT out")
    print("")
# Out:
#  neighbor 14.1.1.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.2.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.3.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.4.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.5.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.6.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.7.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.8.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.9.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.10.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.11.2
#    use neighbor-group ACS-FULL
#    description IXIA_04/03
#
#  neighbor 14.1.12.2
#    use neighbor-group ACS-FULL
# ...

# %%
for i in range(150):
    t = 1401 + i
    l =  i
    p = 256 + i
    k = 1756 + i
    m = format(p, 'x')
    print("   neighbor 2001:db8:140:" + str(m) + "::2")
    print("   remote-as " + str(k))
    print("   description IXIA_05/03")
    print("   address-family ipv6 unicast")
    print("    route-policy PERMIT in")
    print("    route-policy PERMIT out")
    print("")

# %%
for i in range(255):
    t = 2201 + i
    l = 255 + i
    m = format(l, 'x')
    k = 2201 + i
    print("   neighbor 2001:db8:220:" + str(m) + "::2/64")
    print("")
# Out:
#    neighbor 2001:db8:220:ff::2/64
#
#    neighbor 2001:db8:220:100::2/64
#
#    neighbor 2001:db8:220:101::2/64
#
#    neighbor 2001:db8:220:102::2/64
#
#    neighbor 2001:db8:220:103::2/64
#
#    neighbor 2001:db8:220:104::2/64
#
#    neighbor 2001:db8:220:105::2/64
#
#    neighbor 2001:db8:220:106::2/64
#
#    neighbor 2001:db8:220:107::2/64
#
#    neighbor 2001:db8:220:108::2/64
#
#    neighbor 2001:db8:220:109::2/64
#
#    neighbor 2001:db8:220:10a::2/64
#
#    neighbor 2001:db8:220:10b::2/64
#
#    neighbor 2001:db8:220:10c::2/64
#
#    neighbor 2001:db8:220:10d::2/64
#
#    neighbor 2001:db8:220:10e::2/64
#
#    neighbor 2001:db8:220:10f::2/64
#
#    neighbor 2001:db8:220:110::2/64
#
#    neighbor 2001:db8:220:111::2/64
#
#    neighbor 2001:db8:220:112::2/64
#
#    neighbor 2001:db8:220:113::2/64
#
#    neighbor 2001:db8:220:114::2/64
#
#    neighbor 2001:db8:220:115::2/64
#
#    neighbor 2001:db8:220:116::2/64
#
#    neighbor 2001:db8:220:117::2/64
#
# ...

# %%
for i in range(10):
    t = 1551 + i
    l =  i+1
    m = format(l, 'x')
    k = 65220 + i
    print("   neighbor 15.1." + str(l) + ".2")   
    print("   remote-as " + str(t))
    print("   description IXIA_04/03")
    print("   address-family ipv4 unicast")
    print("    route-policy PERMIT in")
    print("    route-policy PERMIT out")
    print("")
# Out:
#    neighbor 15.1.1.2
#    remote-as 1551
#    description IXIA_04/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.1.2.2
#    remote-as 1552
#    description IXIA_04/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.1.3.2
#    remote-as 1553
#    description IXIA_04/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.1.4.2
#    remote-as 1554
#    description IXIA_04/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.1.5.2
#    remote-as 1555
#    description IXIA_04/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.1.6.2
#    remote-as 1556
#    description IXIA_04/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
# ...

# %%
for i in range(45):
    t = 1756 + i
    l =  i
    m = format(l, 'x')
    k = 65220 + i
    print("   neighbor 15.2." + str(l) + ".2")   
    print("   remote-as " + str(t))
    print("   description IXIA_05/03")
    print("   address-family ipv4 unicast")
    print("    route-policy PERMIT in")
    print("    route-policy PERMIT out")
    print("")
# Out:
#    neighbor 15.2.0.2
#    remote-as 1756
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.2.1.2
#    remote-as 1757
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.2.2.2
#    remote-as 1758
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.2.3.2
#    remote-as 1759
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.2.4.2
#    remote-as 1760
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 15.2.5.2
#    remote-as 1761
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
# ...

# %%
for i in range(300):
    t = 1901 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/7/0/15." + str(t))
    print("bfd fast-detect")
    print("cost 50")    
    print("network point-to-point")
    print("")
# Out:
# interface TenGigE0/7/0/15.1901
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1902
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1903
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1904
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1905
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1906
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1907
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1908
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1909
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1910
# bfd fast-detect
# cost 50
# network point-to-point
#
# interface TenGigE0/7/0/15.1911
# bfd fast-detect
# cost 50
# network point-to-point
#
# ...

# %%
for i in range(100):
    t = 1901 + i
    l = 1 + i
    m = format(l, 'x')
    print("no interface HundredGigE0/11/0/2." + str(t))
# Out:
# no interface HundredGigE0/11/0/2.1901
# no interface HundredGigE0/11/0/2.1902
# no interface HundredGigE0/11/0/2.1903
# no interface HundredGigE0/11/0/2.1904
# no interface HundredGigE0/11/0/2.1905
# no interface HundredGigE0/11/0/2.1906
# no interface HundredGigE0/11/0/2.1907
# no interface HundredGigE0/11/0/2.1908
# no interface HundredGigE0/11/0/2.1909
# no interface HundredGigE0/11/0/2.1910
# no interface HundredGigE0/11/0/2.1911
# no interface HundredGigE0/11/0/2.1912
# no interface HundredGigE0/11/0/2.1913
# no interface HundredGigE0/11/0/2.1914
# no interface HundredGigE0/11/0/2.1915
# no interface HundredGigE0/11/0/2.1916
# no interface HundredGigE0/11/0/2.1917
# no interface HundredGigE0/11/0/2.1918
# no interface HundredGigE0/11/0/2.1919
# no interface HundredGigE0/11/0/2.1920
# no interface HundredGigE0/11/0/2.1921
# no interface HundredGigE0/11/0/2.1922
# no interface HundredGigE0/11/0/2.1923
# no interface HundredGigE0/11/0/2.1924
# no interface HundredGigE0/11/0/2.1925
# ...

# %%
for i in range(100):
    t = 1501 + i
    l = 1 + i
    m = format(l, 'x')
    print("no interface TenGigE0/0/0/2." + str(t))
# Out:
# no interface TenGigE0/0/0/2.1501
# no interface TenGigE0/0/0/2.1502
# no interface TenGigE0/0/0/2.1503
# no interface TenGigE0/0/0/2.1504
# no interface TenGigE0/0/0/2.1505
# no interface TenGigE0/0/0/2.1506
# no interface TenGigE0/0/0/2.1507
# no interface TenGigE0/0/0/2.1508
# no interface TenGigE0/0/0/2.1509
# no interface TenGigE0/0/0/2.1510
# no interface TenGigE0/0/0/2.1511
# no interface TenGigE0/0/0/2.1512
# no interface TenGigE0/0/0/2.1513
# no interface TenGigE0/0/0/2.1514
# no interface TenGigE0/0/0/2.1515
# no interface TenGigE0/0/0/2.1516
# no interface TenGigE0/0/0/2.1517
# no interface TenGigE0/0/0/2.1518
# no interface TenGigE0/0/0/2.1519
# no interface TenGigE0/0/0/2.1520
# no interface TenGigE0/0/0/2.1521
# no interface TenGigE0/0/0/2.1522
# no interface TenGigE0/0/0/2.1523
# no interface TenGigE0/0/0/2.1524
# no interface TenGigE0/0/0/2.1525
# no interface TenGigE0/0/0/2.1526
# no interface TenGigE0/0/0/2.1527
# no interface TenGigE0/0/0/2.1528
# ...

# %%
for i in range(300):
    t = 1901 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/7/0/15." + str(t))
    print("  bandwidth 10000000")
    print("")
# Out:
# interface TenGigE0/7/0/15.1901
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1902
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1903
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1904
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1905
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1906
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1907
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1908
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1909
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1910
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1911
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1912
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1913
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1914
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1915
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1916
#   bandwidth 10000000
#
# interface TenGigE0/7/0/15.1917
#   bandwidth 10000000
#
# ...

# %%
for i in range(100):
    t = 1501 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/1." + str(t))
    print("bandwidth 10000000")
    print("")
# Out:
# interface TenGigE0/0/0/1.1501
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1502
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1503
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1504
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1505
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1506
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1507
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1508
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1509
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1510
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1511
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1512
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1513
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1514
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1515
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1516
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1517
# bandwidth 10000000
#
# interface TenGigE0/0/0/1.1518
# bandwidth 10000000
#
# ...

# %%
for i in range(120):
    l = 1 + i
    m = format(l, 'x')
    k = 2001 + i
    print("neighbor 20.1." + str(l) + ".2")
    print("remote-as " + str(k))
    print("description IXIA_05/03")
    print("address-family ipv4 unicast")
    print("route-policy PERMIT in")
    print("route-policy PERMIT out")
    print("")
# Out:
# neighbor 20.1.1.2
# remote-as 2001
# description IXIA_05/03
# address-family ipv4 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 20.1.2.2
# remote-as 2002
# description IXIA_05/03
# address-family ipv4 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 20.1.3.2
# remote-as 2003
# description IXIA_05/03
# address-family ipv4 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 20.1.4.2
# remote-as 2004
# description IXIA_05/03
# address-family ipv4 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 20.1.5.2
# remote-as 2005
# description IXIA_05/03
# address-family ipv4 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 20.1.6.2
# remote-as 2006
# description IXIA_05/03
# address-family ipv4 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 20.1.7.2
# remote-as 2007
# description IXIA_05/03
# address-family ipv4 unicast
# route-policy PERMIT in
# ...

# %%
for i in range(120):
    t = 1601 + i
    l = 1 + i
    m = format(l, 'x')
    k = 65170 + i
    print("neighbor 2001:db8:170:" + str(m) + "::2")
    print("remote-as " + str(k))
    print("description IXIA_04/08")
    print("address-family ipv6 unicast")
    print("route-policy PERMIT in")
    print("route-policy PERMIT out")
    print("")
# Out:
# neighbor 2001:db8:170:1::2
# remote-as 65170
# description IXIA_04/08
# address-family ipv6 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 2001:db8:170:2::2
# remote-as 65171
# description IXIA_04/08
# address-family ipv6 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 2001:db8:170:3::2
# remote-as 65172
# description IXIA_04/08
# address-family ipv6 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 2001:db8:170:4::2
# remote-as 65173
# description IXIA_04/08
# address-family ipv6 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 2001:db8:170:5::2
# remote-as 65174
# description IXIA_04/08
# address-family ipv6 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 2001:db8:170:6::2
# remote-as 65175
# description IXIA_04/08
# address-family ipv6 unicast
# route-policy PERMIT in
# route-policy PERMIT out
#
# neighbor 2001:db8:170:7::2
# remote-as 65176
# ...

# %%
for i in range(100):
    t = 1501 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/1." + str(t))
    print("")
# Out:
# interface TenGigE0/0/0/1.1501
#
# interface TenGigE0/0/0/1.1502
#
# interface TenGigE0/0/0/1.1503
#
# interface TenGigE0/0/0/1.1504
#
# interface TenGigE0/0/0/1.1505
#
# interface TenGigE0/0/0/1.1506
#
# interface TenGigE0/0/0/1.1507
#
# interface TenGigE0/0/0/1.1508
#
# interface TenGigE0/0/0/1.1509
#
# interface TenGigE0/0/0/1.1510
#
# interface TenGigE0/0/0/1.1511
#
# interface TenGigE0/0/0/1.1512
#
# interface TenGigE0/0/0/1.1513
#
# interface TenGigE0/0/0/1.1514
#
# interface TenGigE0/0/0/1.1515
#
# interface TenGigE0/0/0/1.1516
#
# interface TenGigE0/0/0/1.1517
#
# interface TenGigE0/0/0/1.1518
#
# interface TenGigE0/0/0/1.1519
#
# interface TenGigE0/0/0/1.1520
#
# interface TenGigE0/0/0/1.1521
#
# interface TenGigE0/0/0/1.1522
#
# interface TenGigE0/0/0/1.1523
#
# interface TenGigE0/0/0/1.1524
#
# interface TenGigE0/0/0/1.1525
#
# interface TenGigE0/0/0/1.1526
#
# interface TenGigE0/0/0/1.1527
#
# interface TenGigE0/0/0/1.1528
#
# interface TenGigE0/0/0/1.1529
#
# ...

# %%
for i in range(255):
    t = 1901 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface tunnel-te" + str(t))
    print("description IXIA_04/05")
    print("ipv4 unnumbered Loopback0")
    print("signalled-name IXIA_04/05")
    print("priority 3 3")
    print("autoroute announce")
    print("destination 19.19.19." + str(l))
    print("fast-reroute")
    print("record-route")
    print("path-selection metric igp")
    print("path-option 100 dynamic")
    print("logging events link-status")
    print("")
# Out:
# interface tunnel-te1901
# description IXIA_04/05
# ipv4 unnumbered Loopback0
# signalled-name IXIA_04/05
# priority 3 3
# autoroute announce
# destination 19.19.19.1
# fast-reroute
# record-route
# path-selection metric igp
# path-option 100 dynamic
# logging events link-status
#
# interface tunnel-te1902
# description IXIA_04/05
# ipv4 unnumbered Loopback0
# signalled-name IXIA_04/05
# priority 3 3
# autoroute announce
# destination 19.19.19.2
# fast-reroute
# record-route
# path-selection metric igp
# path-option 100 dynamic
# logging events link-status
#
# interface tunnel-te1903
# description IXIA_04/05
# ipv4 unnumbered Loopback0
# signalled-name IXIA_04/05
# priority 3 3
# autoroute announce
# destination 19.19.19.3
# fast-reroute
# record-route
# path-selection metric igp
# path-option 100 dynamic
# logging events link-status
#
# interface tunnel-te1904
# description IXIA_04/05
# ipv4 unnumbered Loopback0
# signalled-name IXIA_04/05
# priority 3 3
# autoroute announce
# ...

# %%
for i in range(45):
    t = 2156 + i
    l =  i 
    m = format(l, 'x')
    print("interface tunnel-te" + str(t))
    print("description IXIA_04/08")
    print("ipv4 unnumbered Loopback0")
    print("signalled-name IXIA_04/08")
    print("priority 3 3")
    print("autoroute announce")
    print("destination 19.19.20." + str(l+1))
    print("fast-reroute")
    print("record-route")
    print("path-selection metric igp")
    print("path-option 100 dynamic")
    print("logging events link-status")
    print("")
# Out:
# interface tunnel-te2156
# description IXIA_04/08
# ipv4 unnumbered Loopback0
# signalled-name IXIA_04/08
# priority 3 3
# autoroute announce
# destination 19.19.20.1
# fast-reroute
# record-route
# path-selection metric igp
# path-option 100 dynamic
# logging events link-status
#
# interface tunnel-te2157
# description IXIA_04/08
# ipv4 unnumbered Loopback0
# signalled-name IXIA_04/08
# priority 3 3
# autoroute announce
# destination 19.19.20.2
# fast-reroute
# record-route
# path-selection metric igp
# path-option 100 dynamic
# logging events link-status
#
# interface tunnel-te2158
# description IXIA_04/08
# ipv4 unnumbered Loopback0
# signalled-name IXIA_04/08
# priority 3 3
# autoroute announce
# destination 19.19.20.3
# fast-reroute
# record-route
# path-selection metric igp
# path-option 100 dynamic
# logging events link-status
#
# interface tunnel-te2159
# description IXIA_04/08
# ipv4 unnumbered Loopback0
# signalled-name IXIA_04/08
# priority 3 3
# autoroute announce
# ...

# %%
for i in range(300):
    t = 19001 + i
    l =  i 
    m = format(l, 'x')
    print("no interface tunnel-te" + str(t))
    print("")
# Out:
# no interface tunnel-te19001
#
# no interface tunnel-te19002
#
# no interface tunnel-te19003
#
# no interface tunnel-te19004
#
# no interface tunnel-te19005
#
# no interface tunnel-te19006
#
# no interface tunnel-te19007
#
# no interface tunnel-te19008
#
# no interface tunnel-te19009
#
# no interface tunnel-te19010
#
# no interface tunnel-te19011
#
# no interface tunnel-te19012
#
# no interface tunnel-te19013
#
# no interface tunnel-te19014
#
# no interface tunnel-te19015
#
# no interface tunnel-te19016
#
# no interface tunnel-te19017
#
# no interface tunnel-te19018
#
# no interface tunnel-te19019
#
# no interface tunnel-te19020
#
# no interface tunnel-te19021
#
# no interface tunnel-te19022
#
# no interface tunnel-te19023
#
# no interface tunnel-te19024
#
# no interface tunnel-te19025
#
# no interface tunnel-te19026
#
# no interface tunnel-te19027
#
# no interface tunnel-te19028
#
# no interface tunnel-te19029
#
# no interface tunnel-te19030
#
# no interface tunnel-te19031
#
# ...

# %%
for i in range(300):
    t = 1901 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/7/0/15." + str(t))
    print("  bfd fast-detect")
    print("")
# Out:
# interface TenGigE0/7/0/15.1901
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1902
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1903
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1904
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1905
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1906
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1907
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1908
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1909
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1910
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1911
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1912
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1913
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1914
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1915
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1916
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1917
#   bfd fast-detect
#
# interface TenGigE0/7/0/15.1918
#   bfd fast-detect
#
# ...

# %%
for i in range(50):
    t = i + 1
    l = 201 + i 
    print("neighbor 20.20.20." + str(t) + " pw-id " + str(l))
# Out:
# neighbor 20.20.20.1 pw-id 201
# neighbor 20.20.20.2 pw-id 202
# neighbor 20.20.20.3 pw-id 203
# neighbor 20.20.20.4 pw-id 204
# neighbor 20.20.20.5 pw-id 205
# neighbor 20.20.20.6 pw-id 206
# neighbor 20.20.20.7 pw-id 207
# neighbor 20.20.20.8 pw-id 208
# neighbor 20.20.20.9 pw-id 209
# neighbor 20.20.20.10 pw-id 210
# neighbor 20.20.20.11 pw-id 211
# neighbor 20.20.20.12 pw-id 212
# neighbor 20.20.20.13 pw-id 213
# neighbor 20.20.20.14 pw-id 214
# neighbor 20.20.20.15 pw-id 215
# neighbor 20.20.20.16 pw-id 216
# neighbor 20.20.20.17 pw-id 217
# neighbor 20.20.20.18 pw-id 218
# neighbor 20.20.20.19 pw-id 219
# neighbor 20.20.20.20 pw-id 220
# neighbor 20.20.20.21 pw-id 221
# neighbor 20.20.20.22 pw-id 222
# neighbor 20.20.20.23 pw-id 223
# neighbor 20.20.20.24 pw-id 224
# neighbor 20.20.20.25 pw-id 225
# neighbor 20.20.20.26 pw-id 226
# neighbor 20.20.20.27 pw-id 227
# neighbor 20.20.20.28 pw-id 228
# neighbor 20.20.20.29 pw-id 229
# neighbor 20.20.20.30 pw-id 230
# ...

# %%
for i in range(100):
    t = i + 100
    print("2001:200:" + str(t) + "::/48 le 128," )
# Out:
# 2001:200:100::/48 le 128,
# 2001:200:101::/48 le 128,
# 2001:200:102::/48 le 128,
# 2001:200:103::/48 le 128,
# 2001:200:104::/48 le 128,
# 2001:200:105::/48 le 128,
# 2001:200:106::/48 le 128,
# 2001:200:107::/48 le 128,
# 2001:200:108::/48 le 128,
# 2001:200:109::/48 le 128,
# 2001:200:110::/48 le 128,
# 2001:200:111::/48 le 128,
# 2001:200:112::/48 le 128,
# 2001:200:113::/48 le 128,
# 2001:200:114::/48 le 128,
# 2001:200:115::/48 le 128,
# 2001:200:116::/48 le 128,
# 2001:200:117::/48 le 128,
# 2001:200:118::/48 le 128,
# 2001:200:119::/48 le 128,
# 2001:200:120::/48 le 128,
# 2001:200:121::/48 le 128,
# 2001:200:122::/48 le 128,
# 2001:200:123::/48 le 128,
# 2001:200:124::/48 le 128,
# 2001:200:125::/48 le 128,
# 2001:200:126::/48 le 128,
# 2001:200:127::/48 le 128,
# 2001:200:128::/48 le 128,
# 2001:200:129::/48 le 128,
# 2001:200:130::/48 le 128,
# 2001:200:131::/48 le 128,
# 2001:200:132::/48 le 128,
# 2001:200:133::/48 le 128,
# 2001:200:134::/48 le 128,
# ...

# %%
for i in range(100):
    i = i + 
    print("10.152." + str(i) + '.0/24 le 32,')
# Out:
# 10.152.1.0/24 le 32,
# 10.152.2.0/24 le 32,
# 10.152.3.0/24 le 32,
# 10.152.4.0/24 le 32,
# 10.152.5.0/24 le 32,
# 10.152.6.0/24 le 32,
# 10.152.7.0/24 le 32,
# 10.152.8.0/24 le 32,
# 10.152.9.0/24 le 32,
# 10.152.10.0/24 le 32,
# 10.152.11.0/24 le 32,
# 10.152.12.0/24 le 32,
# 10.152.13.0/24 le 32,
# 10.152.14.0/24 le 32,
# 10.152.15.0/24 le 32,
# 10.152.16.0/24 le 32,
# 10.152.17.0/24 le 32,
# 10.152.18.0/24 le 32,
# 10.152.19.0/24 le 32,
# 10.152.20.0/24 le 32,
# 10.152.21.0/24 le 32,
# 10.152.22.0/24 le 32,
# 10.152.23.0/24 le 32,
# 10.152.24.0/24 le 32,
# 10.152.25.0/24 le 32,
# 10.152.26.0/24 le 32,
# 10.152.27.0/24 le 32,
# 10.152.28.0/24 le 32,
# 10.152.29.0/24 le 32,
# 10.152.30.0/24 le 32,
# 10.152.31.0/24 le 32,
# 10.152.32.0/24 le 32,
# 10.152.33.0/24 le 32,
# 10.152.34.0/24 le 32,
# 10.152.35.0/24 le 32,
# 10.152.36.0/24 le 32,
# 10.152.37.0/24 le 32,
# 10.152.38.0/24 le 32,
# 10.152.39.0/24 le 32,
# 10.152.40.0/24 le 32,
# 10.152.41.0/24 le 32,
# 10.152.42.0/24 le 32,
# ...

# %%
for i in range(100):
    t = i
    l = 1 + i
    m = format(l, 'x')
    print("2001:269:" + str(m) + "::/48 le 128,")
# Out:
# 2001:269:1::/48 le 128,
# 2001:269:2::/48 le 128,
# 2001:269:3::/48 le 128,
# 2001:269:4::/48 le 128,
# 2001:269:5::/48 le 128,
# 2001:269:6::/48 le 128,
# 2001:269:7::/48 le 128,
# 2001:269:8::/48 le 128,
# 2001:269:9::/48 le 128,
# 2001:269:a::/48 le 128,
# 2001:269:b::/48 le 128,
# 2001:269:c::/48 le 128,
# 2001:269:d::/48 le 128,
# 2001:269:e::/48 le 128,
# 2001:269:f::/48 le 128,
# 2001:269:10::/48 le 128,
# 2001:269:11::/48 le 128,
# 2001:269:12::/48 le 128,
# 2001:269:13::/48 le 128,
# 2001:269:14::/48 le 128,
# 2001:269:15::/48 le 128,
# 2001:269:16::/48 le 128,
# 2001:269:17::/48 le 128,
# 2001:269:18::/48 le 128,
# 2001:269:19::/48 le 128,
# 2001:269:1a::/48 le 128,
# 2001:269:1b::/48 le 128,
# 2001:269:1c::/48 le 128,
# 2001:269:1d::/48 le 128,
# 2001:269:1e::/48 le 128,
# 2001:269:1f::/48 le 128,
# 2001:269:20::/48 le 128,
# 2001:269:21::/48 le 128,
# 2001:269:22::/48 le 128,
# 2001:269:23::/48 le 128,
# 2001:269:24::/48 le 128,
# 2001:269:25::/48 le 128,
# ...

# %%
for i in range(10):
    t = 1551 + i
    l = 1 + i
    m = format(l, 'x')
    k = 65170 + i
    print("interface TenGigE0/0/0/4." + str(t))
    print("description IXIA_04/03")
    print("service-policy input Core-Qos")
    print("service-policy output Core-Qos")
    print("ipv6 address 2001:db8:210:" + str(m) + "::1/64")
    print("dampening")
    print("encapsulation dot1q " + str(t))
    print("")
# Out:
# interface TenGigE0/0/0/1.2101
# description IXIA_04/08
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv6 address 2001:db8:210:1::1/64
# dampening
# encapsulation dot1q 2101
#
# interface TenGigE0/0/0/1.2102
# description IXIA_04/08
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv6 address 2001:db8:210:2::1/64
# dampening
# encapsulation dot1q 2102
#
# interface TenGigE0/0/0/1.2103
# description IXIA_04/08
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv6 address 2001:db8:210:3::1/64
# dampening
# encapsulation dot1q 2103
#
# interface TenGigE0/0/0/1.2104
# description IXIA_04/08
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv6 address 2001:db8:210:4::1/64
# dampening
# encapsulation dot1q 2104
#
# interface TenGigE0/0/0/1.2105
# description IXIA_04/08
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv6 address 2001:db8:210:5::1/64
# dampening
# encapsulation dot1q 2105
#
# ...

# %%
for i in range(90):
    t = 2101 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/1." + str(t) + " shutdown")
    print("")
# Out:
# interface TenGigE0/0/0/1.2101 shutdown
#
# interface TenGigE0/0/0/1.2102 shutdown
#
# interface TenGigE0/0/0/1.2103 shutdown
#
# interface TenGigE0/0/0/1.2104 shutdown
#
# interface TenGigE0/0/0/1.2105 shutdown
#
# interface TenGigE0/0/0/1.2106 shutdown
#
# interface TenGigE0/0/0/1.2107 shutdown
#
# interface TenGigE0/0/0/1.2108 shutdown
#
# interface TenGigE0/0/0/1.2109 shutdown
#
# interface TenGigE0/0/0/1.2110 shutdown
#
# interface TenGigE0/0/0/1.2111 shutdown
#
# interface TenGigE0/0/0/1.2112 shutdown
#
# interface TenGigE0/0/0/1.2113 shutdown
#
# interface TenGigE0/0/0/1.2114 shutdown
#
# interface TenGigE0/0/0/1.2115 shutdown
#
# interface TenGigE0/0/0/1.2116 shutdown
#
# interface TenGigE0/0/0/1.2117 shutdown
#
# interface TenGigE0/0/0/1.2118 shutdown
#
# interface TenGigE0/0/0/1.2119 shutdown
#
# interface TenGigE0/0/0/1.2120 shutdown
#
# interface TenGigE0/0/0/1.2121 shutdown
#
# interface TenGigE0/0/0/1.2122 shutdown
#
# interface TenGigE0/0/0/1.2123 shutdown
#
# ...

# %%
for i in range(90):
    t = 1511 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/2." + str(t) + ' shutdown')
    print("")
# Out:
# interface TenGigE0/0/0/2.1511 shutdown
#
# interface TenGigE0/0/0/2.1512 shutdown
#
# interface TenGigE0/0/0/2.1513 shutdown
#
# interface TenGigE0/0/0/2.1514 shutdown
#
# interface TenGigE0/0/0/2.1515 shutdown
#
# interface TenGigE0/0/0/2.1516 shutdown
#
# interface TenGigE0/0/0/2.1517 shutdown
#
# interface TenGigE0/0/0/2.1518 shutdown
#
# interface TenGigE0/0/0/2.1519 shutdown
#
# interface TenGigE0/0/0/2.1520 shutdown
#
# interface TenGigE0/0/0/2.1521 shutdown
#
# interface TenGigE0/0/0/2.1522 shutdown
#
# interface TenGigE0/0/0/2.1523 shutdown
#
# interface TenGigE0/0/0/2.1524 shutdown
#
# interface TenGigE0/0/0/2.1525 shutdown
#
# interface TenGigE0/0/0/2.1526 shutdown
#
# interface TenGigE0/0/0/2.1527 shutdown
#
# interface TenGigE0/0/0/2.1528 shutdown
#
# interface TenGigE0/0/0/2.1529 shutdown
#
# interface TenGigE0/0/0/2.1530 shutdown
#
# interface TenGigE0/0/0/2.1531 shutdown
#
# interface TenGigE0/0/0/2.1532 shutdown
#
# interface TenGigE0/0/0/2.1533 shutdown
#
# ...

# %%
for i in range(295):
    t = 1305 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface HundredGigE0/11/0/2." + str(t))
    print("no service-policy input Core-Qos")
    print("no service-policy output Core-Qos")
    print("")
# Out:
# interface HundredGigE0/11/0/2.1305
# no service-policy input Core-Qos
# no service-policy output Core-Qos
#
# interface HundredGigE0/11/0/2.1306
# no service-policy input Core-Qos
# no service-policy output Core-Qos
#
# interface HundredGigE0/11/0/2.1307
# no service-policy input Core-Qos
# no service-policy output Core-Qos
#
# interface HundredGigE0/11/0/2.1308
# no service-policy input Core-Qos
# no service-policy output Core-Qos
#
# interface HundredGigE0/11/0/2.1309
# no service-policy input Core-Qos
# no service-policy output Core-Qos
#
# interface HundredGigE0/11/0/2.1310
# no service-policy input Core-Qos
# no service-policy output Core-Qos
#
# interface HundredGigE0/11/0/2.1311
# no service-policy input Core-Qos
# no service-policy output Core-Qos
#
# interface HundredGigE0/11/0/2.1312
# no service-policy input Core-Qos
# no service-policy output Core-Qos
#
# interface HundredGigE0/11/0/2.1313
# no service-policy input Core-Qos
# no service-policy output Core-Qos
#
# ...

# %%
for i in range(10):
    t = 1201 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface HundredGigE0/3/0/1." + str(t))
    print("description IXIA_05/03")
    print("service-policy input Core-Qos")
    print("service-policy output Core-Qos") 
    print("ipv4 address 12.1." + str(l) + ".1 255.255.255.0")
    print("ipv6 address 2001:db8:120:" + str(m) + "::1/64")
    print("dampening")
    print("encapsulation dot1q " + str(t))
    print("")
# Out:
# interface HundredGigE0/3/0/1.1201
# description IXIA_05/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 12.1.1.1 255.255.255.0
# ipv6 address 2001:db8:120:1::1/64
# dampening
# encapsulation dot1q 1201
#
# interface HundredGigE0/3/0/1.1202
# description IXIA_05/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 12.1.2.1 255.255.255.0
# ipv6 address 2001:db8:120:2::1/64
# dampening
# encapsulation dot1q 1202
#
# interface HundredGigE0/3/0/1.1203
# description IXIA_05/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 12.1.3.1 255.255.255.0
# ipv6 address 2001:db8:120:3::1/64
# dampening
# encapsulation dot1q 1203
#
# interface HundredGigE0/3/0/1.1204
# description IXIA_05/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 12.1.4.1 255.255.255.0
# ipv6 address 2001:db8:120:4::1/64
# dampening
# encapsulation dot1q 1204
#
# interface HundredGigE0/3/0/1.1205
# ...

# %%
for i in range(10):
    t = 1201 + i
    l =  i + 1
    p = 256 + i
    k = 1201 + i
    m = format(p, 'x')
    print("   neighbor 12.1." + str(l) + ".2")
    print("   remote-as " + str(k))
    print("   description IXIA_05/03")
    print("   address-family ipv4 unicast")
    print("    route-policy PERMIT in")
    print("    route-policy PERMIT out")
    print("")
# Out:
#    neighbor 12.1.1.2
#    remote-as 1201
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 12.1.2.2
#    remote-as 1202
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 12.1.3.2
#    remote-as 1203
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 12.1.4.2
#    remote-as 1204
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 12.1.5.2
#    remote-as 1205
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 12.1.6.2
#    remote-as 1206
#    description IXIA_05/03
#    address-family ipv4 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
# ...

# %%
for i in range(10):
    t = 1201 + i
    l =  i+1
    p =  i + 1
    k = 1201 + i
    m = format(p, 'x')
    print("   neighbor 2001:db8:120:" + str(m) + "::2")
    print("   remote-as " + str(k))
    print("   description IXIA_05/03")
    print("   address-family ipv6 unicast")
    print("    route-policy PERMIT in")
    print("    route-policy PERMIT out")
    print("")
# Out:
#    neighbor 2001:db8:120:1::2
#    remote-as 1201
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:120:2::2
#    remote-as 1202
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:120:3::2
#    remote-as 1203
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:120:4::2
#    remote-as 1204
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:120:5::2
#    remote-as 1205
#    description IXIA_05/03
#    address-family ipv6 unicast
#     route-policy PERMIT in
#     route-policy PERMIT out
#
#    neighbor 2001:db8:120:6::2
#    remote-as 1206
#    description IXIA_05/03
#    address-family ipv6 unicast
# ...

# %%
for i in range(350):
    t = 2211 + i
    l = 1 + i
    m = format(l, 'x')
    print("no interface HundredGigE0/3/0/1." + str(t))
    print("")
# Out:
# no interface HundredGigE0/3/0/1.2211
#
# no interface HundredGigE0/3/0/1.2212
#
# no interface HundredGigE0/3/0/1.2213
#
# no interface HundredGigE0/3/0/1.2214
#
# no interface HundredGigE0/3/0/1.2215
#
# no interface HundredGigE0/3/0/1.2216
#
# no interface HundredGigE0/3/0/1.2217
#
# no interface HundredGigE0/3/0/1.2218
#
# no interface HundredGigE0/3/0/1.2219
#
# no interface HundredGigE0/3/0/1.2220
#
# no interface HundredGigE0/3/0/1.2221
#
# no interface HundredGigE0/3/0/1.2222
#
# no interface HundredGigE0/3/0/1.2223
#
# no interface HundredGigE0/3/0/1.2224
#
# no interface HundredGigE0/3/0/1.2225
#
# no interface HundredGigE0/3/0/1.2226
#
# no interface HundredGigE0/3/0/1.2227
#
# no interface HundredGigE0/3/0/1.2228
#
# no interface HundredGigE0/3/0/1.2229
#
# no interface HundredGigE0/3/0/1.2230
#
# no interface HundredGigE0/3/0/1.2231
#
# no interface HundredGigE0/3/0/1.2232
#
# no interface HundredGigE0/3/0/1.2233
#
# no interface HundredGigE0/3/0/1.2234
#
# ...

# %%
for i in range(100):
    t = 1501 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface HundredGigE0/3/0/1." + str(t))
    print("ipv6 address 2001:db8:150:" + str(m) + "::1/64")
    print("")
# Out:
# interface HundredGigE0/3/0/1.1501
# ipv6 address 2001:db8:150:1::1/64
#
# interface HundredGigE0/3/0/1.1502
# ipv6 address 2001:db8:150:2::1/64
#
# interface HundredGigE0/3/0/1.1503
# ipv6 address 2001:db8:150:3::1/64
#
# interface HundredGigE0/3/0/1.1504
# ipv6 address 2001:db8:150:4::1/64
#
# interface HundredGigE0/3/0/1.1505
# ipv6 address 2001:db8:150:5::1/64
#
# interface HundredGigE0/3/0/1.1506
# ipv6 address 2001:db8:150:6::1/64
#
# interface HundredGigE0/3/0/1.1507
# ipv6 address 2001:db8:150:7::1/64
#
# interface HundredGigE0/3/0/1.1508
# ipv6 address 2001:db8:150:8::1/64
#
# interface HundredGigE0/3/0/1.1509
# ipv6 address 2001:db8:150:9::1/64
#
# interface HundredGigE0/3/0/1.1510
# ipv6 address 2001:db8:150:a::1/64
#
# interface HundredGigE0/3/0/1.1511
# ipv6 address 2001:db8:150:b::1/64
#
# interface HundredGigE0/3/0/1.1512
# ipv6 address 2001:db8:150:c::1/64
#
# interface HundredGigE0/3/0/1.1513
# ipv6 address 2001:db8:150:d::1/64
#
# interface HundredGigE0/3/0/1.1514
# ...

# %%
for i in range(300):
    t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/4." + str(t))
    #print("ipv6 address 2001:db8:150:" + str(m) + "::1/64")
    print("  bfd fast-detect")
    print("  cost 50")
    print("  network point-to-point")
    print("")
# Out:
# interface TenGigE0/0/0/4.1101
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1102
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1103
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1104
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1105
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1106
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1107
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1108
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1109
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1110
#   bfd fast-detect
#   cost 50
#   network point-to-point
#
# interface TenGigE0/0/0/4.1111
#   bfd fast-detect
#   cost 50
# ...

# %%
for i in range(255):
    t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/4." + str(t))
    print("description IXIA_04/03")
    print("service-policy input Core-Qos")
    print("service-policy output Core-Qos")
    #print("vrf LTE")    
    print("ipv4 address 11.1." + str(l) + ".1 255.255.255.0")
    print("ipv6 address 2001:db8:110:" + str(m) + "::1/64")
    print("dampening")
    print("encapsulation dot1q " + str(t))
    print("")
# Out:
# interface TenGigE0/0/0/4.1101
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 11.1.1.1 255.255.255.0
# ipv6 address 2001:db8:110:1::1/64
# dampening
# encapsulation dot1q 1101
#
# interface TenGigE0/0/0/4.1102
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 11.1.2.1 255.255.255.0
# ipv6 address 2001:db8:110:2::1/64
# dampening
# encapsulation dot1q 1102
#
# interface TenGigE0/0/0/4.1103
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 11.1.3.1 255.255.255.0
# ipv6 address 2001:db8:110:3::1/64
# dampening
# encapsulation dot1q 1103
#
# interface TenGigE0/0/0/4.1104
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 11.1.4.1 255.255.255.0
# ipv6 address 2001:db8:110:4::1/64
# dampening
# encapsulation dot1q 1104
#
# interface TenGigE0/0/0/4.1105
# ...

# %%
for i in range(45):
    t = 1356 + i
    l =  i
    p = 256 + i
    m = format(p, 'x')
    print("interface TenGigE0/0/0/4." + str(t))
    print("description IXIA_04/03")
    print("service-policy input Core-Qos")
    print("service-policy output Core-Qos")
    #print("vrf JCOMINT") 
    print("ipv4 address 11.2." + str(l) + ".1 255.255.255.0")
    print("ipv6 address 2001:db8:110:" + str(m) + "::1/64")
    #print("dampening")
    print("encapsulation dot1q " + str(t))
    print("")
# Out:
# interface TenGigE0/0/0/4.1356
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 11.2.0.1 255.255.255.0
# ipv6 address 2001:db8:110:100::1/64
# encapsulation dot1q 1356
#
# interface TenGigE0/0/0/4.1357
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 11.2.1.1 255.255.255.0
# ipv6 address 2001:db8:110:101::1/64
# encapsulation dot1q 1357
#
# interface TenGigE0/0/0/4.1358
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 11.2.2.1 255.255.255.0
# ipv6 address 2001:db8:110:102::1/64
# encapsulation dot1q 1358
#
# interface TenGigE0/0/0/4.1359
# description IXIA_04/03
# service-policy input Core-Qos
# service-policy output Core-Qos
# ipv4 address 11.2.3.1 255.255.255.0
# ipv6 address 2001:db8:110:103::1/64
# encapsulation dot1q 1359
#
# interface TenGigE0/0/0/4.1360
# description IXIA_04/03
# service-policy input Core-Qos
# ...

# %%
for i in range(300):
    t = 1201 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/2." + str(t))
    print("cost 1")
    print("network point-to-point")
    #print("service-policy input Core-Qos")
    #print("service-policy output Core-Qos")
    #print("vrf JCOMINT")    
    #print("ipv4 address 12.1." + str(l) + ".1 255.255.255.0")
    #print("ipv6 address 2001:db8:120:" + str(m) + "::1/64")
    #print("dampening")
    #print("encapsulation dot1q " + str(t))
    print("")
# Out:
# interface TenGigE0/0/0/2.1201
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1202
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1203
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1204
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1205
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1206
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1207
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1208
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1209
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1210
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1211
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1212
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1213
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1214
# cost 1
# network point-to-point
#
# interface TenGigE0/0/0/2.1215
# cost 1
# ...

# %%
for i in range(10):
    t = 1811 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/2." + str(t))
    print("description IXIA_05/03_JCOMVOIP")
    #print("service-policy input Core-Qos")
    #print("service-policy output Core-Qos")
    print("vrf JCOMVOIP")    
    print("ipv4 address 18.1." + str(l) + ".1 255.255.255.0")
    print("ipv6 address 2001:db8:180:" + str(m) + "::1/64")
    #print("dampening")
    print("encapsulation dot1q " + str(t))
    print("")
# Out:
# interface TenGigE0/0/0/2.1801
# description IXIA_05/03_JCOMCDN
# vrf JCOMCDN
# ipv4 address 18.1.1.1 255.255.255.0
# ipv6 address 2001:db8:180:1::1/64
# encapsulation dot1q 1801
#
# interface TenGigE0/0/0/2.1802
# description IXIA_05/03_JCOMCDN
# vrf JCOMCDN
# ipv4 address 18.1.2.1 255.255.255.0
# ipv6 address 2001:db8:180:2::1/64
# encapsulation dot1q 1802
#
# interface TenGigE0/0/0/2.1803
# description IXIA_05/03_JCOMCDN
# vrf JCOMCDN
# ipv4 address 18.1.3.1 255.255.255.0
# ipv6 address 2001:db8:180:3::1/64
# encapsulation dot1q 1803
#
# interface TenGigE0/0/0/2.1804
# description IXIA_05/03_JCOMCDN
# vrf JCOMCDN
# ipv4 address 18.1.4.1 255.255.255.0
# ipv6 address 2001:db8:180:4::1/64
# encapsulation dot1q 1804
#
# interface TenGigE0/0/0/2.1805
# description IXIA_05/03_JCOMCDN
# vrf JCOMCDN
# ipv4 address 18.1.5.1 255.255.255.0
# ipv6 address 2001:db8:180:5::1/64
# encapsulation dot1q 1805
#
# interface TenGigE0/0/0/2.1806
# description IXIA_05/03_JCOMCDN
# vrf JCOMCDN
# ...

# %%
for i in range(10):
    t = 1811 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface TenGigE0/0/0/2." + str(t))
    print("bfd fast-detect")
    print("cost 50")
    print("network point-to-point")
    #print("service-policy input Core-Qos")
    #print("service-policy output Core-Qos")
    #print("vrf JCOMCDN")    
    #print("ipv4 address 18.1." + str(l) + ".1 255.255.255.0")
    #print("ipv6 address 2001:db8:180:" + str(m) + "::1/64")
    #print("dampening")
    #print("encapsulation dot1q " + str(t))
    print("")
# Out:
# interface TenGigE0/0/0/2.1801
# bfd fast-detect
# cost 10
# network point-to-point
#
# interface TenGigE0/0/0/2.1802
# bfd fast-detect
# cost 10
# network point-to-point
#
# interface TenGigE0/0/0/2.1803
# bfd fast-detect
# cost 10
# network point-to-point
#
# interface TenGigE0/0/0/2.1804
# bfd fast-detect
# cost 10
# network point-to-point
#
# interface TenGigE0/0/0/2.1805
# bfd fast-detect
# cost 10
# network point-to-point
#
# interface TenGigE0/0/0/2.1806
# bfd fast-detect
# cost 10
# network point-to-point
#
# interface TenGigE0/0/0/2.1807
# bfd fast-detect
# cost 10
# network point-to-point
#
# interface TenGigE0/0/0/2.1808
# bfd fast-detect
# cost 10
# network point-to-point
#
# interface TenGigE0/0/0/2.1809
# bfd fast-detect
# cost 10
# network point-to-point
#
# interface TenGigE0/0/0/2.1810
# bfd fast-detect
# cost 10
# network point-to-point

# %%
for i in range(40):
    t = 111 + i
    l =  i+1
    m = format(l, 'x')
    k = 65220 + i
    print(" interface Vlan" + str(t))   
    print(" ip address 10.10." + str(t) + ".1 255.255.255.0")
    print("")
# Out:
#  interface Vlan111
#  ip address 10.10.111.1 255.255.255.0
#
#  interface Vlan112
#  ip address 10.10.112.1 255.255.255.0
#
#  interface Vlan113
#  ip address 10.10.113.1 255.255.255.0
#
#  interface Vlan114
#  ip address 10.10.114.1 255.255.255.0
#
#  interface Vlan115
#  ip address 10.10.115.1 255.255.255.0
#
#  interface Vlan116
#  ip address 10.10.116.1 255.255.255.0
#
#  interface Vlan117
#  ip address 10.10.117.1 255.255.255.0
#
#  interface Vlan118
#  ip address 10.10.118.1 255.255.255.0
#
#  interface Vlan119
#  ip address 10.10.119.1 255.255.255.0
#
#  interface Vlan120
#  ip address 10.10.120.1 255.255.255.0
#
#  interface Vlan121
#  ip address 10.10.121.1 255.255.255.0
#
#  interface Vlan122
#  ip address 10.10.122.1 255.255.255.0
#
#  interface Vlan123
#  ip address 10.10.123.1 255.255.255.0
#
#  interface Vlan124
#  ip address 10.10.124.1 255.255.255.0
#
#  interface Vlan125
#  ip address 10.10.125.1 255.255.255.0
#
#  interface Vlan126
# ...

# %%
for i in range(40):
    t = 111 + i
    print(" network 10.10." + str(t) + ".1 0.0.0.255 area 0")
# Out:
#  network 10.10.111.1 0.0.0.255 area 0
#  network 10.10.112.1 0.0.0.255 area 0
#  network 10.10.113.1 0.0.0.255 area 0
#  network 10.10.114.1 0.0.0.255 area 0
#  network 10.10.115.1 0.0.0.255 area 0
#  network 10.10.116.1 0.0.0.255 area 0
#  network 10.10.117.1 0.0.0.255 area 0
#  network 10.10.118.1 0.0.0.255 area 0
#  network 10.10.119.1 0.0.0.255 area 0
#  network 10.10.120.1 0.0.0.255 area 0
#  network 10.10.121.1 0.0.0.255 area 0
#  network 10.10.122.1 0.0.0.255 area 0
#  network 10.10.123.1 0.0.0.255 area 0
#  network 10.10.124.1 0.0.0.255 area 0
#  network 10.10.125.1 0.0.0.255 area 0
#  network 10.10.126.1 0.0.0.255 area 0
#  network 10.10.127.1 0.0.0.255 area 0
#  network 10.10.128.1 0.0.0.255 area 0
#  network 10.10.129.1 0.0.0.255 area 0
#  network 10.10.130.1 0.0.0.255 area 0
#  network 10.10.131.1 0.0.0.255 area 0
#  network 10.10.132.1 0.0.0.255 area 0
#  network 10.10.133.1 0.0.0.255 area 0
#  network 10.10.134.1 0.0.0.255 area 0
#  network 10.10.135.1 0.0.0.255 area 0
# ...

# %%
for i in range(150):
    t =  + i
    l =  i
    p = 256 + i
    k = 2456 + i
    m = format(p, 'x')
    print("   no neighbor 22.2." + str(l) + ".2")
    #print("   remote-as " + str(k))
    #print("   description IXIA_05/03")
    #print("   address-family ipv4 unicast")
    #print("    route-policy PERMIT in")
    #print("    route-policy PERMIT out")
    print("")

# %%
for i in range(150):
    t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print("interface tunnel-te" + str(t))
    print(" ")
# Out:
# interface tunnel-te1101
#
# interface tunnel-te1102
#
# interface tunnel-te1103
#
# interface tunnel-te1104
#
# interface tunnel-te1105
#
# interface tunnel-te1106
#
# interface tunnel-te1107
#
# interface tunnel-te1108
#
# interface tunnel-te1109
#
# interface tunnel-te1110
#
# interface tunnel-te1111
#
# interface tunnel-te1112
#
# interface tunnel-te1113
#
# interface tunnel-te1114
#
# interface tunnel-te1115
#
# interface tunnel-te1116
#
# interface tunnel-te1117
#
# interface tunnel-te1118
#
# interface tunnel-te1119
#
# interface tunnel-te1120
#
# interface tunnel-te1121
#
# interface tunnel-te1122
#
# interface tunnel-te1123
#
# interface tunnel-te1124
#
# interface tunnel-te1125
#
# interface tunnel-te1126
#
# interface tunnel-te1127
#
# interface tunnel-te1128
#
# interface tunnel-te1129
#
# interface tunnel-te1130
#
# interface tunnel-te1131
#
# interface tunnel-te1132
#
# interface tunnel-te1133
#
# interface tunnel-te1134
#
# interface tunnel-te1135
#
# ...

# %%
for i in range(255):
    #t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print(" 130.1." + str(l) + ".0/24 11.1.1.2 ")
    print(" ")
# Out:
#  130.1.1.0/24 11.1.1.2
#
#  130.1.2.0/24 11.1.1.2
#
#  130.1.3.0/24 11.1.1.2
#
#  130.1.4.0/24 11.1.1.2
#
#  130.1.5.0/24 11.1.1.2
#
#  130.1.6.0/24 11.1.1.2
#
#  130.1.7.0/24 11.1.1.2
#
#  130.1.8.0/24 11.1.1.2
#
#  130.1.9.0/24 11.1.1.2
#
#  130.1.10.0/24 11.1.1.2
#
#  130.1.11.0/24 11.1.1.2
#
#  130.1.12.0/24 11.1.1.2
#
#  130.1.13.0/24 11.1.1.2
#
#  130.1.14.0/24 11.1.1.2
#
#  130.1.15.0/24 11.1.1.2
#
#  130.1.16.0/24 11.1.1.2
#
#  130.1.17.0/24 11.1.1.2
#
#  130.1.18.0/24 11.1.1.2
#
#  130.1.19.0/24 11.1.1.2
#
#  130.1.20.0/24 11.1.1.2
#
#  130.1.21.0/24 11.1.1.2
#
#  130.1.22.0/24 11.1.1.2
#
#  130.1.23.0/24 11.1.1.2
#
#  130.1.24.0/24 11.1.1.2
#
#  130.1.25.0/24 11.1.1.2
#
#  130.1.26.0/24 11.1.1.2
#
#  130.1.27.0/24 11.1.1.2
#
#  130.1.28.0/24 11.1.1.2
#
#  130.1.29.0/24 11.1.1.2
#
#  130.1.30.0/24 11.1.1.2
#
#  130.1.31.0/24 11.1.1.2
#
#  130.1.32.0/24 11.1.1.2
#
#  130.1.33.0/24 11.1.1.2
#
#  130.1.34.0/24 11.1.1.2
#
#  130.1.35.0/24 11.1.1.2
#
#  130.1.36.0/24 11.1.1.2
#
# ...

# %%
for i in range(255):
    #t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print(" 130.2." + str(l) + ".0/24 11.1.1.2 ")
    print(" ")
# Out:
#  130.2.1.0/24 11.1.1.2
#
#  130.2.2.0/24 11.1.1.2
#
#  130.2.3.0/24 11.1.1.2
#
#  130.2.4.0/24 11.1.1.2
#
#  130.2.5.0/24 11.1.1.2
#
#  130.2.6.0/24 11.1.1.2
#
#  130.2.7.0/24 11.1.1.2
#
#  130.2.8.0/24 11.1.1.2
#
#  130.2.9.0/24 11.1.1.2
#
#  130.2.10.0/24 11.1.1.2
#
#  130.2.11.0/24 11.1.1.2
#
#  130.2.12.0/24 11.1.1.2
#
#  130.2.13.0/24 11.1.1.2
#
#  130.2.14.0/24 11.1.1.2
#
#  130.2.15.0/24 11.1.1.2
#
#  130.2.16.0/24 11.1.1.2
#
#  130.2.17.0/24 11.1.1.2
#
#  130.2.18.0/24 11.1.1.2
#
#  130.2.19.0/24 11.1.1.2
#
#  130.2.20.0/24 11.1.1.2
#
#  130.2.21.0/24 11.1.1.2
#
#  130.2.22.0/24 11.1.1.2
#
#  130.2.23.0/24 11.1.1.2
#
#  130.2.24.0/24 11.1.1.2
#
#  130.2.25.0/24 11.1.1.2
#
#  130.2.26.0/24 11.1.1.2
#
#  130.2.27.0/24 11.1.1.2
#
#  130.2.28.0/24 11.1.1.2
#
#  130.2.29.0/24 11.1.1.2
#
#  130.2.30.0/24 11.1.1.2
#
#  130.2.31.0/24 11.1.1.2
#
#  130.2.32.0/24 11.1.1.2
#
#  130.2.33.0/24 11.1.1.2
#
#  130.2.34.0/24 11.1.1.2
#
#  130.2.35.0/24 11.1.1.2
#
#  130.2.36.0/24 11.1.1.2
#
# ...

# %%
for i in range(255):
    #t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print(" 130.3." + str(l) + ".0/24 11.1.1.2 ")
    print(" ")
# Out:
#  130.3.1.0/24 11.1.1.2
#
#  130.3.2.0/24 11.1.1.2
#
#  130.3.3.0/24 11.1.1.2
#
#  130.3.4.0/24 11.1.1.2
#
#  130.3.5.0/24 11.1.1.2
#
#  130.3.6.0/24 11.1.1.2
#
#  130.3.7.0/24 11.1.1.2
#
#  130.3.8.0/24 11.1.1.2
#
#  130.3.9.0/24 11.1.1.2
#
#  130.3.10.0/24 11.1.1.2
#
#  130.3.11.0/24 11.1.1.2
#
#  130.3.12.0/24 11.1.1.2
#
#  130.3.13.0/24 11.1.1.2
#
#  130.3.14.0/24 11.1.1.2
#
#  130.3.15.0/24 11.1.1.2
#
#  130.3.16.0/24 11.1.1.2
#
#  130.3.17.0/24 11.1.1.2
#
#  130.3.18.0/24 11.1.1.2
#
#  130.3.19.0/24 11.1.1.2
#
#  130.3.20.0/24 11.1.1.2
#
#  130.3.21.0/24 11.1.1.2
#
#  130.3.22.0/24 11.1.1.2
#
#  130.3.23.0/24 11.1.1.2
#
#  130.3.24.0/24 11.1.1.2
#
#  130.3.25.0/24 11.1.1.2
#
#  130.3.26.0/24 11.1.1.2
#
#  130.3.27.0/24 11.1.1.2
#
#  130.3.28.0/24 11.1.1.2
#
#  130.3.29.0/24 11.1.1.2
#
#  130.3.30.0/24 11.1.1.2
#
#  130.3.31.0/24 11.1.1.2
#
#  130.3.32.0/24 11.1.1.2
#
#  130.3.33.0/24 11.1.1.2
#
#  130.3.34.0/24 11.1.1.2
#
#  130.3.35.0/24 11.1.1.2
#
#  130.3.36.0/24 11.1.1.2
#
# ...

# %%
for i in range(235):
    #t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print(" 130.4." + str(l) + ".0/24 11.1.1.2 ")
    print(" ")
# Out:
#  130.4.1.0/24 11.1.1.2
#
#  130.4.2.0/24 11.1.1.2
#
#  130.4.3.0/24 11.1.1.2
#
#  130.4.4.0/24 11.1.1.2
#
#  130.4.5.0/24 11.1.1.2
#
#  130.4.6.0/24 11.1.1.2
#
#  130.4.7.0/24 11.1.1.2
#
#  130.4.8.0/24 11.1.1.2
#
#  130.4.9.0/24 11.1.1.2
#
#  130.4.10.0/24 11.1.1.2
#
#  130.4.11.0/24 11.1.1.2
#
#  130.4.12.0/24 11.1.1.2
#
#  130.4.13.0/24 11.1.1.2
#
#  130.4.14.0/24 11.1.1.2
#
#  130.4.15.0/24 11.1.1.2
#
#  130.4.16.0/24 11.1.1.2
#
#  130.4.17.0/24 11.1.1.2
#
#  130.4.18.0/24 11.1.1.2
#
#  130.4.19.0/24 11.1.1.2
#
#  130.4.20.0/24 11.1.1.2
#
#  130.4.21.0/24 11.1.1.2
#
#  130.4.22.0/24 11.1.1.2
#
#  130.4.23.0/24 11.1.1.2
#
#  130.4.24.0/24 11.1.1.2
#
#  130.4.25.0/24 11.1.1.2
#
#  130.4.26.0/24 11.1.1.2
#
#  130.4.27.0/24 11.1.1.2
#
#  130.4.28.0/24 11.1.1.2
#
#  130.4.29.0/24 11.1.1.2
#
#  130.4.30.0/24 11.1.1.2
#
#  130.4.31.0/24 11.1.1.2
#
#  130.4.32.0/24 11.1.1.2
#
#  130.4.33.0/24 11.1.1.2
#
#  130.4.34.0/24 11.1.1.2
#
#  130.4.35.0/24 11.1.1.2
#
#  130.4.36.0/24 11.1.1.2
#
# ...

# %%
for i in range(255):
    #t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print(" 2001:130:1:" + str(m) + "::/64 2001:db8:110:1::1/64")
    print(" ")
# Out:
#  2001:130:1:1::/64 2001:db8:110:1::1/64
#
#  2001:130:1:2::/64 2001:db8:110:1::1/64
#
#  2001:130:1:3::/64 2001:db8:110:1::1/64
#
#  2001:130:1:4::/64 2001:db8:110:1::1/64
#
#  2001:130:1:5::/64 2001:db8:110:1::1/64
#
#  2001:130:1:6::/64 2001:db8:110:1::1/64
#
#  2001:130:1:7::/64 2001:db8:110:1::1/64
#
#  2001:130:1:8::/64 2001:db8:110:1::1/64
#
#  2001:130:1:9::/64 2001:db8:110:1::1/64
#
#  2001:130:1:a::/64 2001:db8:110:1::1/64
#
#  2001:130:1:b::/64 2001:db8:110:1::1/64
#
#  2001:130:1:c::/64 2001:db8:110:1::1/64
#
#  2001:130:1:d::/64 2001:db8:110:1::1/64
#
#  2001:130:1:e::/64 2001:db8:110:1::1/64
#
#  2001:130:1:f::/64 2001:db8:110:1::1/64
#
#  2001:130:1:10::/64 2001:db8:110:1::1/64
#
#  2001:130:1:11::/64 2001:db8:110:1::1/64
#
#  2001:130:1:12::/64 2001:db8:110:1::1/64
#
#  2001:130:1:13::/64 2001:db8:110:1::1/64
#
#  2001:130:1:14::/64 2001:db8:110:1::1/64
#
#  2001:130:1:15::/64 2001:db8:110:1::1/64
#
#  2001:130:1:16::/64 2001:db8:110:1::1/64
#
# ...

# %%
for i in range(255):
    #t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print(" 2001:130:2:" + str(m) + "::/64 2001:db8:110:1::1/64")
    print(" ")
# Out:
#  2001:130:2:1::/64 2001:db8:110:1::1/64
#
#  2001:130:2:2::/64 2001:db8:110:1::1/64
#
#  2001:130:2:3::/64 2001:db8:110:1::1/64
#
#  2001:130:2:4::/64 2001:db8:110:1::1/64
#
#  2001:130:2:5::/64 2001:db8:110:1::1/64
#
#  2001:130:2:6::/64 2001:db8:110:1::1/64
#
#  2001:130:2:7::/64 2001:db8:110:1::1/64
#
#  2001:130:2:8::/64 2001:db8:110:1::1/64
#
#  2001:130:2:9::/64 2001:db8:110:1::1/64
#
#  2001:130:2:a::/64 2001:db8:110:1::1/64
#
#  2001:130:2:b::/64 2001:db8:110:1::1/64
#
#  2001:130:2:c::/64 2001:db8:110:1::1/64
#
#  2001:130:2:d::/64 2001:db8:110:1::1/64
#
#  2001:130:2:e::/64 2001:db8:110:1::1/64
#
#  2001:130:2:f::/64 2001:db8:110:1::1/64
#
#  2001:130:2:10::/64 2001:db8:110:1::1/64
#
#  2001:130:2:11::/64 2001:db8:110:1::1/64
#
#  2001:130:2:12::/64 2001:db8:110:1::1/64
#
#  2001:130:2:13::/64 2001:db8:110:1::1/64
#
#  2001:130:2:14::/64 2001:db8:110:1::1/64
#
#  2001:130:2:15::/64 2001:db8:110:1::1/64
#
#  2001:130:2:16::/64 2001:db8:110:1::1/64
#
# ...

# %%
for i in range(255):
    #t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print(" 2001:130:3:" + str(m) + "::/64 2001:db8:110:1::1/64")
    print(" ")
# Out:
#  2001:130:3:1::/64 2001:db8:110:1::1/64
#
#  2001:130:3:2::/64 2001:db8:110:1::1/64
#
#  2001:130:3:3::/64 2001:db8:110:1::1/64
#
#  2001:130:3:4::/64 2001:db8:110:1::1/64
#
#  2001:130:3:5::/64 2001:db8:110:1::1/64
#
#  2001:130:3:6::/64 2001:db8:110:1::1/64
#
#  2001:130:3:7::/64 2001:db8:110:1::1/64
#
#  2001:130:3:8::/64 2001:db8:110:1::1/64
#
#  2001:130:3:9::/64 2001:db8:110:1::1/64
#
#  2001:130:3:a::/64 2001:db8:110:1::1/64
#
#  2001:130:3:b::/64 2001:db8:110:1::1/64
#
#  2001:130:3:c::/64 2001:db8:110:1::1/64
#
#  2001:130:3:d::/64 2001:db8:110:1::1/64
#
#  2001:130:3:e::/64 2001:db8:110:1::1/64
#
#  2001:130:3:f::/64 2001:db8:110:1::1/64
#
#  2001:130:3:10::/64 2001:db8:110:1::1/64
#
#  2001:130:3:11::/64 2001:db8:110:1::1/64
#
#  2001:130:3:12::/64 2001:db8:110:1::1/64
#
#  2001:130:3:13::/64 2001:db8:110:1::1/64
#
#  2001:130:3:14::/64 2001:db8:110:1::1/64
#
#  2001:130:3:15::/64 2001:db8:110:1::1/64
#
#  2001:130:3:16::/64 2001:db8:110:1::1/64
#
# ...

# %%
for i in range(235):
    #t = 1101 + i
    l = 1 + i
    m = format(l, 'x')
    print(" 2001:130:4:" + str(m) + "::/64 2001:db8:110:1::1/64")
    print(" ")
# Out:
#  2001:130:4:1::/64 2001:db8:110:1::1/64
#
#  2001:130:4:2::/64 2001:db8:110:1::1/64
#
#  2001:130:4:3::/64 2001:db8:110:1::1/64
#
#  2001:130:4:4::/64 2001:db8:110:1::1/64
#
#  2001:130:4:5::/64 2001:db8:110:1::1/64
#
#  2001:130:4:6::/64 2001:db8:110:1::1/64
#
#  2001:130:4:7::/64 2001:db8:110:1::1/64
#
#  2001:130:4:8::/64 2001:db8:110:1::1/64
#
#  2001:130:4:9::/64 2001:db8:110:1::1/64
#
#  2001:130:4:a::/64 2001:db8:110:1::1/64
#
#  2001:130:4:b::/64 2001:db8:110:1::1/64
#
#  2001:130:4:c::/64 2001:db8:110:1::1/64
#
#  2001:130:4:d::/64 2001:db8:110:1::1/64
#
#  2001:130:4:e::/64 2001:db8:110:1::1/64
#
#  2001:130:4:f::/64 2001:db8:110:1::1/64
#
#  2001:130:4:10::/64 2001:db8:110:1::1/64
#
#  2001:130:4:11::/64 2001:db8:110:1::1/64
#
#  2001:130:4:12::/64 2001:db8:110:1::1/64
#
#  2001:130:4:13::/64 2001:db8:110:1::1/64
#
#  2001:130:4:14::/64 2001:db8:110:1::1/64
#
#  2001:130:4:15::/64 2001:db8:110:1::1/64
#
#  2001:130:4:16::/64 2001:db8:110:1::1/64
#
# ...

# %%
for i in range(150):
    t = 1901 + i
    l = 1 + i
    m = format(l, 'x')
    print(" interface tunnel-te" + str(t))

    print("")
# Out:
#  interface tunnel-te1901
#
#  interface tunnel-te1902
#
#  interface tunnel-te1903
#
#  interface tunnel-te1904
#
#  interface tunnel-te1905
#
#  interface tunnel-te1906
#
#  interface tunnel-te1907
#
#  interface tunnel-te1908
#
#  interface tunnel-te1909
#
#  interface tunnel-te1910
#
#  interface tunnel-te1911
#
#  interface tunnel-te1912
#
#  interface tunnel-te1913
#
#  interface tunnel-te1914
#
#  interface tunnel-te1915
#
#  interface tunnel-te1916
#
#  interface tunnel-te1917
#
#  interface tunnel-te1918
#
#  interface tunnel-te1919
#
#  interface tunnel-te1920
#
#  interface tunnel-te1921
#
#  interface tunnel-te1922
#
#  interface tunnel-te1923
#
#  interface tunnel-te1924
#
#  interface tunnel-te1925
#
#  interface tunnel-te1926
#
#  interface tunnel-te1927
#
#  interface tunnel-te1928
#
#  interface tunnel-te1929
#
#  interface tunnel-te1930
#
#  interface tunnel-te1931
#
#  interface tunnel-te1932
#
#  interface tunnel-te1933
#
#  interface tunnel-te1934
#
# ...
